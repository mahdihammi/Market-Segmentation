# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans,AgglomerativeClustering,DBSCAN,SpectralClustering
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn import tree
from sklearn import metrics

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/content/Customer Data.csv')

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %% [markdown]
# # EDA

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
def check_ratio(df, column):

  ratio = len(df[df[column].isnull()]) / len(df)
  percentage = ratio * 100

  return percentage

# %%
check_ratio(df,'MINIMUM_PAYMENTS')
# Out:
# 3.4972067039106145

# %% [markdown]
# The percentage of the null values of minimum payements is 3.49%
#
#
# *   We're going to replace null values with mean

# %%
df['MINIMUM_PAYMENTS'] = df['MINIMUM_PAYMENTS'].fillna(df['MINIMUM_PAYMENTS'].mean())
df['CREDIT_LIMIT'] = df['CREDIT_LIMIT'].fillna(df['CREDIT_LIMIT'].mean())

# %%
df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
df.drop(columns=['CUST_ID'], axis=1, inplace=True)

# %%
plt.figure(figsize=(30,45))

for i,col in enumerate(df.columns):
  if df[col].dtype != 'object':
    ax = plt.subplot(9,2, i+1)
    sns.kdeplot(df[col], ax=ax)
    plt.xlabel(col)

plt.show()

# %%
plt.figure(figsize=(25,75))

for i in range(0,17):
  plt.subplot(17,1,i+1)
  sns.distplot(df[df.columns[i]])
  plt.title(df.columns[i])

plt.subplots_adjust(hspace=0.5)  # Adjust the height between subplots
plt.show()

# %% [markdown]
# None of the features has a normal distribution

# %%
plt.figure(figsize=(12,12))

corr = df.corr()
sns.heatmap(corr, annot=True)
plt.show()

# %%
# unstack -> pivots the level of the indexed columns in a stacked dataframe
corr_pairs = corr.unstack()

print(corr_pairs)
# Out:
# BALANCE  BALANCE                   1.000000
#          BALANCE_FREQUENCY         0.322412
#          PURCHASES                 0.181261
#          ONEOFF_PURCHASES          0.164350
#          INSTALLMENTS_PURCHASES    0.126469
#                                      ...
# TENURE   CREDIT_LIMIT              0.139034
#          PAYMENTS                  0.106136
#          MINIMUM_PAYMENTS          0.057257
#          PRC_FULL_PAYMENT         -0.016486
#          TENURE                    1.000000
# Length: 289, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(ascending=False)
sorted_pairs
# Out:
# BALANCE                 BALANCE                             1.000000
# BALANCE_FREQUENCY       BALANCE_FREQUENCY                   1.000000
# PRC_FULL_PAYMENT        PRC_FULL_PAYMENT                    1.000000
# MINIMUM_PAYMENTS        MINIMUM_PAYMENTS                    1.000000
# PAYMENTS                PAYMENTS                            1.000000
#                                                               ...
# CASH_ADVANCE_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY   -0.262958
#                         PURCHASES_FREQUENCY                -0.308478
# PURCHASES_FREQUENCY     CASH_ADVANCE_FREQUENCY             -0.308478
# BALANCE                 PRC_FULL_PAYMENT                   -0.318959
# PRC_FULL_PAYMENT        BALANCE                            -0.318959
# Length: 289, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs > 0.50) & (sorted_pairs < 1)]

high_corr = high_corr.drop_duplicates()

high_corr
# Out:
# ONEOFF_PURCHASES                  PURCHASES                           0.916845
# PURCHASES_FREQUENCY               PURCHASES_INSTALLMENTS_FREQUENCY    0.862934
# CASH_ADVANCE_TRX                  CASH_ADVANCE_FREQUENCY              0.799561
# PURCHASES                         PURCHASES_TRX                       0.689561
#                                   INSTALLMENTS_PURCHASES              0.679896
# CASH_ADVANCE_TRX                  CASH_ADVANCE                        0.656498
# CASH_ADVANCE_FREQUENCY            CASH_ADVANCE                        0.628522
# PURCHASES_TRX                     INSTALLMENTS_PURCHASES              0.628108
# PURCHASES                         PAYMENTS                            0.603264
# PURCHASES_FREQUENCY               PURCHASES_TRX                       0.568430
# ONEOFF_PURCHASES                  PAYMENTS                            0.567292
# PURCHASES_TRX                     ONEOFF_PURCHASES                    0.545523
# ...

# %% [markdown]
# # Feature Scaling

# %%
scalar=StandardScaler()
scaled_df = scalar.fit_transform(df)

# %%
scaled_df
# Out:
# array([[-0.73198937, -0.24943448, -0.42489974, ..., -0.31096755,
#         -0.52555097,  0.36067954],
#        [ 0.78696085,  0.13432467, -0.46955188, ...,  0.08931021,
#          0.2342269 ,  0.36067954],
#        [ 0.44713513,  0.51808382, -0.10766823, ..., -0.10166318,
#         -0.52555097,  0.36067954],
#        ...,
#        [-0.7403981 , -0.18547673, -0.40196519, ..., -0.33546549,
#          0.32919999, -4.12276757],
#        [-0.74517423, -0.18547673, -0.46955188, ..., -0.34690648,
#          0.32919999, -4.12276757],
#        [-0.57257511, -0.88903307,  0.04214581, ..., -0.33294642,
#         -0.52555097, -4.12276757]])

# %% [markdown]
# # Model Building

# %%
inertia = []
range_value = range(1,15)
for i in range_value:
  kmean = KMeans(n_clusters = i)
  kmean.fit_predict(pd.DataFrame(scaled_df))
  inertia.append(kmean.inertia_)

plt.plot(range_value, inertia, 'bx-')
plt.xlabel('K values')
plt.ylabel('Inertia')
plt.xticks(range(1,15))
plt.title('Elbow Method')
plt.show()

# %% [markdown]
# # Dimensionality Reduction : PCA

# %%
pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_df)
pca_df = pd.DataFrame(data=principal_components ,columns=["PCA1","PCA2"])
pca_df
# Out:
#           PCA1      PCA2
# 0    -1.682219 -1.076452
# 1    -1.138280  2.506474
# 2     0.969669 -0.383522
# 3    -0.873633  0.043161
# 4    -1.599431 -0.688581
# ...        ...       ...
# 8945 -0.359631 -2.016145
# 8946 -0.564378 -1.639124
# 8947 -0.926206 -1.810785
# 8948 -2.336546 -0.657964
# 8949 -0.556420 -0.400463
#
# [8950 rows x 2 columns]

# %%
kmeans_model=KMeans(4)
kmeans_model.fit_predict(scaled_df)
pca_df_kmeans= pd.concat([pca_df,pd.DataFrame({'cluster':kmeans_model.labels_})],axis=1)

# %%
pca_df_kmeans
# Out:
#           PCA1      PCA2  cluster
# 0    -1.682219 -1.076452        1
# 1    -1.138280  2.506474        2
# 2     0.969669 -0.383522        3
# 3    -0.873633  0.043161        1
# 4    -1.599431 -0.688581        1
# ...        ...       ...      ...
# 8945 -0.359631 -2.016145        3
# 8946 -0.564378 -1.639124        3
# 8947 -0.926206 -1.810785        3
# 8948 -2.336546 -0.657964        1
# 8949 -0.556420 -0.400463        1
#
# [8950 rows x 3 columns]

# %%
plt.figure(figsize=(8,8))
ax=sns.scatterplot(x="PCA1",y="PCA2",hue="cluster",data=pca_df_kmeans,palette=['red','green','blue','black'])
plt.title("Clustering using K-Means Algorithm")
plt.show()

# %%
# find all cluster centers
cluster_centers = pd.DataFrame(data=kmeans_model.cluster_centers_,columns=[df.columns])
# inverse transform the data
cluster_centers = scalar.inverse_transform(cluster_centers)
cluster_centers = pd.DataFrame(data=cluster_centers,columns=[df.columns])
cluster_centers
# Out:
#        BALANCE BALANCE_FREQUENCY    PURCHASES ONEOFF_PURCHASES  \
# 0  3551.153761          0.986879  7681.620098      5095.878826
# 1  1011.751528          0.789871   269.973466       209.853863
# 2  4602.462714          0.968415   501.896219       320.373681
# 3   894.907458          0.934734  1236.178934       593.974874
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0            2587.208264   653.638891            0.946418
# 1              60.386625   595.759339            0.170146
# 2             181.607404  4520.724309            0.287731
# 3             642.478274   210.570626            0.885165
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   0.739031                         0.788060
# 1                   0.086281                         0.080578
# 2                   0.138934                         0.185516
# 3                   0.297070                         0.711842
#
# ...

# %%
cluster_df = pd.concat([df,pd.DataFrame({'Cluster':kmeans_model.labels_})],axis=1)

cluster_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
cluster_df['Cluster'].unique()
# Out:
# array([1, 2, 3, 0], dtype=int32)

# %%
cluster_1_df = cluster_df[cluster_df["Cluster"]==0]
cluster_1_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 6      627.260806           1.000000    7091.01           6402.63
# 21    6369.531318           1.000000    6359.95           5910.04
# 57    2386.330629           1.000000    5217.62           4789.09
# 84    1935.362486           1.000000    4915.60           4515.34
# 90    9381.255094           1.000000    5100.07           1147.83
# ...           ...                ...        ...               ...
# 8215  4436.557694           1.000000    6005.90           5838.38
# 8541  3326.323283           1.000000    8209.77           2218.28
# 8662   599.909949           1.000000    4947.32           3149.59
# 8689   368.318662           0.909091    8053.95           8053.95
# 8737  2533.618119           0.909091    5633.83           2985.92
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 6                     688.38      0.000000             1.000000
# ...

# %%
cluster_2_df = cluster_df[cluster_df["Cluster"]==1]
cluster_2_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# 8     1014.926473           1.000000     861.49            661.49
# 9      152.225975           0.545455    1281.60           1281.60
# ...           ...                ...        ...               ...
# 8939   728.352548           1.000000     734.40            734.40
# 8943     5.871712           0.500000      20.90             20.90
# 8944   193.571722           0.833333    1012.73           1012.73
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                       95.4      0.000000             0.166667
# ...

# %%
cluster_3_df = cluster_df[cluster_df["Cluster"]==2]
cluster_3_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 1     3202.467416           0.909091       0.00              0.00
# 15    6886.213231           1.000000    1611.70              0.00
# 23    3800.151377           0.818182    4248.35           3454.56
# 24    5368.571219           1.000000       0.00              0.00
# 28    7152.864372           1.000000     387.05            204.55
# ...           ...                ...        ...               ...
# 8857  2330.222764           1.000000    1320.00              0.00
# 8858   812.934042           1.000000      50.00             50.00
# 8869  2171.222526           1.000000     791.18            791.18
# 8915   381.341657           1.000000      78.00              0.00
# 8941  5967.475270           0.833333     214.55              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 1                       0.00   6442.945483             0.000000
# ...

# %%
cluster_4_df = cluster_df[cluster_df["Cluster"] == 3]
cluster_4_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 2     2495.148862           1.000000     773.17            773.17
# 5     1809.828751           1.000000    1333.28              0.00
# 7     1823.652743           1.000000     436.20              0.00
# 10    1293.124939           1.000000     920.12              0.00
# 12    1516.928620           1.000000    3217.99           2500.23
# ...           ...                ...        ...               ...
# 8940   130.838554           1.000000     591.24              0.00
# 8942    40.829749           1.000000     113.28              0.00
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 2                       0.00           0.0             1.000000
# ...

# %%
sns.countplot(x='Cluster', data=cluster_df)
# Out:
# <Axes: xlabel='Cluster', ylabel='count'>

# %% [markdown]
# Cluster 1 and 2 have the most data points

# %%
for c in cluster_df.drop(['Cluster'],axis=1):
    grid= sns.FacetGrid(cluster_df, col='Cluster')
    grid= grid.map(plt.hist, c)
plt.show()

# %%
import joblib
joblib.dump(kmeans_model, "kmeans_model.pkl")
# Out:
# ['kmeans_model.pkl']

# %%
cluster_df.to_csv('clustered_data_customer.csv')

# %%
cluster_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
plt.figure(figsize=(18,10))

plt.scatter(cluster_1_df['BALANCE'], cluster_1_df['PAYMENTS'],color='red')
plt.scatter(cluster_2_df['BALANCE'], cluster_2_df['PAYMENTS'],color='blue')
plt.scatter(cluster_3_df['BALANCE'], cluster_3_df['PAYMENTS'],color='green')
plt.scatter(cluster_4_df['BALANCE'], cluster_4_df['PAYMENTS'],color='black')



plt.show()

# %% [markdown]
# in the plot of the clusters of the PCA data, you can see clearly the clusters and interpret them => this is why Dimensionality Reduction
# is important when you have high-dimensional data, as it can help in visualizing and understanding the data better, as well as reducing computational complexity.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot for each cluster
ax.scatter(cluster_1_df['BALANCE'], cluster_1_df['PAYMENTS'], cluster_1_df['CREDIT_LIMIT'], color='red', label='Cluster 1')
ax.scatter(cluster_2_df['BALANCE'], cluster_2_df['PAYMENTS'], cluster_2_df['CREDIT_LIMIT'], color='blue', label='Cluster 2')
ax.scatter(cluster_3_df['BALANCE'], cluster_3_df['PAYMENTS'], cluster_3_df['CREDIT_LIMIT'], color='green', label='Cluster 3')
ax.scatter(cluster_4_df['BALANCE'], cluster_4_df['PAYMENTS'], cluster_4_df['CREDIT_LIMIT'], color='black', label='Cluster 4')

# Set labels and title
ax.set_xlabel('BALANCE')
ax.set_ylabel('PAYMENTS')
ax.set_zlabel('CREDIT_LIMIT')
# Out:
# Text(0.5, 0, 'CREDIT_LIMIT')

# %% [markdown]
# # Train and Test the model accuracy using decision tree

# %%
X = cluster_df.drop(['Cluster'], axis=1)
y = cluster_df['Cluster']

X_train, X_test, y_train, y_test =train_test_split(X, y, test_size=0.3)

# %%
X_train
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 8499    16.065938           0.545455     154.45              0.00
# 6462   276.932920           0.454545       0.00              0.00
# 4766    10.358325           0.454545      98.83             98.83
# 2562  1581.742203           1.000000       0.00              0.00
# 5703  1450.649137           1.000000       0.00              0.00
# ...           ...                ...        ...               ...
# 1762  2833.613641           1.000000    1387.52            526.12
# 830   4115.739163           1.000000       0.00              0.00
# 3226   250.493739           1.000000     500.67            500.67
# 293   3992.261885           1.000000       0.00              0.00
# 5472  2306.698723           0.727273   12784.51          11246.07
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 8499                  154.45      0.000000             0.416667
# ...

# %%
#Decision_Tree
model= DecisionTreeClassifier(criterion="entropy")
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
#Confusion_Matrix
print(metrics.confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[ 110    1    3   13]
#  [   0 1149   15   27]
#  [   1   28  298   10]
#  [  11   21   18  980]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.88       127
#            1       0.96      0.96      0.96      1191
#            2       0.89      0.88      0.89       337
#            3       0.95      0.95      0.95      1030
#
#     accuracy                           0.94      2685
#    macro avg       0.93      0.92      0.92      2685
# weighted avg       0.94      0.94      0.94      2685

# %%
import pickle
filename = 'final_model.sav'
pickle.dump(model, open(filename, 'wb'))

# some time later...

# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, y_test)
print(result,'% Acuuracy')
# Out:
# 0.9448789571694599 % Acuuracy
